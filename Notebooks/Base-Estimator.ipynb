# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer, KNNImputer, MissingIndicator
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder, MinMaxScaler, PowerTransformer, OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from sklearn import set_config
set_config(transform_output='pandas')

# %%
df = pd.read_csv('final_data.csv')

# %%
df.sample(10)
# Out:
#       batting_team  bowling_team          city  current_score  balls_left  \
# 66717  West Indies       England        London            208           0
# 24611    Australia  South Africa  Johannesburg            169          11
# 53733   Bangladesh     Sri Lanka       Colombo            130          20
# 54076     Pakistan  South Africa     Centurion             52          83
# 13552     Pakistan       England       Karachi             93          53
# 29585    Sri Lanka      Pakistan        London             48          95
# 7600       England      Pakistan       Karachi            129          41
# 62998   Bangladesh      Pakistan        Lahore             52          70
# 38345     Pakistan         India        Mirpur             40          74
# 33032      England      Pakistan    Manchester             80          59
#
#        wickets_left        crr  last_five  runs_x
# 66717             2  10.400000       53.0     208
# 24611             5   9.302752       41.0     196
# 53733             5   7.800000       45.0     155
# 54076             9   8.432432       44.0     195
# 13552            10   8.328358       40.0     166
# 29585            10  11.520000       46.0     150
# 7600              7   9.797468       48.0     221
# 62998            10   6.240000       36.0     141
# 38345             5   5.217391       22.0      83
# 33032             8   7.868852       54.0     131

# %%
df.isna().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
df_temp = df.copy()

# %%
df_temp.shape
# Out:
# (71885, 9)

# %%
X = df_temp.drop(columns=['runs_x'])
y = df_temp['runs_x']

# %%
X_train, X_test, y_train , y_test = train_test_split(X,y,test_size=0.2, random_state = 1)

# %%
X_train.shape
# Out:
# (57508, 8)

# %%
X_train.columns
# Out:
# Index(['batting_team', 'bowling_team', 'city', 'current_score', 'balls_left',
#        'wickets_left', 'crr', 'last_five'],
#       dtype='object')

# %%
num_cols = ['current_score','balls_left','wickets_left','crr','last_five']

nominal_cat_cols = ['batting_team', 'bowling_team', 'city']

# %%
# column transformer
preprocessor= ColumnTransformer(transformers=[
    ('nominal_encode',OneHotEncoder(drop='first',sparse_output=False),nominal_cat_cols)
],remainder='passthrough')

preprocessor.set_output(transform='pandas')
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('nominal_encode',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['batting_team', 'bowling_team', 'city'])])

# %%
processing_pipeline = Pipeline(steps=[
                                ("preprocess",preprocessor),
                                ("scaling",StandardScaler()),
                                ("model",LinearRegression())
                            ])

processing_pipeline
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal_encode',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('scaling', StandardScaler()), ('model', LinearRegression())])

# %%
processing_pipeline.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal_encode',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('scaling', StandardScaler()), ('model', LinearRegression())])

# %%
y_pred = processing_pipeline.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

print(f"The R2 score is {r2_score(y_test,y_pred)}")
print(f"The MAE error is {mean_absolute_error(y_test,y_pred)}")
# Out:
# The R2 score is 0.6934866127993256
# The MAE error is 13.666049544326134

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(processing_pipeline,
                         X_train,
                         y_train,
                         scoring="neg_mean_absolute_error",
                         cv=5,n_jobs=-1)

print(f"The cross-validation MAE is {-scores.mean()}")
# Out:
# The cross-validation MAE is 13.531806051643311

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, HistGradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor

# %%
processing_pipeline = Pipeline(steps=[
                                ("preprocess",preprocessor),
                                ("scaling",StandardScaler()),
                                ("model",XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
                            ])

processing_pipeline
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal_encode',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('scaling', StandardScaler()),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytre...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.2,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=12, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=1000, n_jobs=None,
#                               num_parallel_tree=None, random_state=1, ...))])

# %%
processing_pipeline.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal_encode',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('scaling', StandardScaler()),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytre...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.2,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=12, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=1000, n_jobs=None,
#                               num_parallel_tree=None, random_state=1, ...))])

# %%
y_pred = processing_pipeline.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

print(f"The R2 score is {r2_score(y_test,y_pred)}")
print(f"The MAE error is {mean_absolute_error(y_test,y_pred)}")
# Out:
# The R2 score is 0.9848944544792175
# The MAE error is 1.9422072172164917

# %%
processing_pipeline = Pipeline(steps=[
                                ("preprocess",preprocessor),
                                ("scaling",StandardScaler()),
                                ("model",GradientBoostingRegressor(n_estimators=184, learning_rate=0.2327591798889126, max_depth= 17))
                            ])

processing_pipeline
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal_encode',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('scaling', StandardScaler()),
#                 ('model',
#                  GradientBoostingRegressor(learning_rate=0.2327591798889126,
#                                            max_depth=17, n_estimators=184))])

# %%
processing_pipeline.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal_encode',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('scaling', StandardScaler()),
#                 ('model',
#                  GradientBoostingRegressor(learning_rate=0.2327591798889126,
#                                            max_depth=17, n_estimators=184))])

# %%
y_pred = processing_pipeline.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

print(f"The R2 score is {r2_score(y_test,y_pred)}")
print(f"The MAE error is {mean_absolute_error(y_test,y_pred)}")
# Out:
# The R2 score is 0.9822164896939378
# The MAE error is 1.9246871734484794

# %%
from sklearn.ensemble import RandomForestRegressor
processing_pipeline = Pipeline(steps=[
                                ("preprocess",preprocessor),
                                ("scaling",StandardScaler()),
                                ("model",RandomForestRegressor(n_estimators=201,max_depth=13,max_features=None,min_samples_split=2,min_samples_leaf=1,max_samples=0.7136902216842659))
                            ])

processing_pipeline
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal_encode',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('scaling', StandardScaler()),
#                 ('model',
#                  RandomForestRegressor(max_depth=13, max_features=None,
#                                        max_samples=0.7136902216842659,
#                                        n_estimators=201))])

# %%
processing_pipeline.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal_encode',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('scaling', StandardScaler()),
#                 ('model',
#                  RandomForestRegressor(max_depth=13, max_features=None,
#                                        max_samples=0.7136902216842659,
#                                        n_estimators=201))])

# %%
y_pred = processing_pipeline.predict(X_test)

# %%
print(f"The R2 score is {r2_score(y_test,y_pred)}")
print(f"The MAE error is {mean_absolute_error(y_test,y_pred)}")
# Out:
# The R2 score is 0.8427221310656158
# The MAE error is 9.508533578020497
